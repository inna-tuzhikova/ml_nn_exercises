# %%
import numpy as np
import pandas as pd

from keras.models import Sequential, Model
from keras.optimizers import rmsprop
from keras.layers import Dense, Conv2D, GlobalAveragePooling2D,  MaxPooling2D, Flatten, Dropout, BatchNormalization, Activation, Input, Lambda 
from keras.utils import to_categorical
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, TensorBoard
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.backend import tf as ktf

# from keras.preprocessing.image import 

from sklearn.model_selection import train_test_split

import cv2

from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def load(train_fn: str, test_fn: str, n_lines_train, n_lines_test):
    
    def read_csv(file_name, n_lines, label=True):
        x = np.ndarray(shape=(n_lines, 3072))
        y = []
        with open(file_name, 'r') as f_in:
            f_in.readline()
            for i in range(n_lines):
                line = f_in.readline().split('"')
                x[i] = [int(pix) for pix in line[1].split(',')]
                if label:
                    l_name = line[2].strip(',').strip()
                    y.append(LABELS.index(l_name))
        return x, y
    
    x_train, y_train = read_csv(train_fn, n_lines_train)
    x_test, _ = read_csv(test_fn, n_lines_test, label=False)    
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2)
    
    return (x_train, y_train, x_val, y_val), x_test


def predict(clf,
            X_test: np.array,
            output_fn: str):
    y_pred = clf.predict_classes(X_test)
    y_pred = [LABELS[pred] for pred in y_pred]
    test_df = pd.DataFrame(data={'Category': y_pred})
    test_df.to_csv(output_fn, index_label='Id')
    return y_pred

# %%
def show_random_images(ds, labels, h=5, w=5):
    idxs = np.random.randint(0, ds.shape[0] - 1, size=w * h).tolist()
    
    plt.figure(figsize=(1.5 * w, 1.5 * h))
    for i, idx in enumerate(idxs):
        plt.subplot(h, w, i + 1)
        image = ds[idx].reshape(32, 32, 3)
        image = image.astype(np.uint8)
        plt.imshow(image)
        plt.title(LABELS[labels[idx]] if labels is not None else '?')
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout()
    plt.show()

# %%
def show_random_images_by_class(x, labels, l_text, n_classes, img_per_class=10):
    inch_per_pic = 1
    fig, plots = plt.subplots(n_classes, img_per_class)
    fig.set_size_inches(inch_per_pic * img_per_class, inch_per_pic * n_classes)

    for cls in range(n_classes):
        imgs = x[np.argwhere(labels == cls)[:, 0].flatten()]
        imgs = imgs[np.random.choice(imgs.shape[0], size=img_per_class, replace=False)]
        plots[cls, 0].set_ylabel(l_text[cls], va='center', ha='right',rotation=0, size=15)
        for i in range(img_per_class):
            plots[cls, i].imshow(imgs[i], cmap='gray')
            plots[cls, i].set_xticks([])
            plots[cls, i].set_yticks([])
    fig.tight_layout()

# %%
def show_most_confident_predictions(ds, model, h=5, w=5, reverse=False):
    n_img = min(h * w, ds.shape[0])
    
    preds = model.predict(ds, verbose=0)
    if reverse:
        extreame_conf = np.argsort(np.max(preds, axis=1))[:n_img]
    else:
        extreame_conf = np.argsort(np.max(preds, axis=1))[-n_img::-1]
    x = ds[extreame_conf]
    preds = [preds[i] for i in extreame_conf]
    
    plt.figure(figsize=(1.5 * w, 1.5 * h))
    for i in range(n_img):
        plt.subplot(h, w, i + 1)
        image = x[i].reshape(image_height, image_width, n_channels)
        plt.imshow(image)
        title = '%s\n%0.2f%%' % (LABELS[np.argmax(preds[i])], 100 * np.max(preds[i]))
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout()

# %%
def predict_random_images(ds, model, h=5, w=5):
    idxs = np.random.randint(0, ds.shape[0] - 1, size=w * h).tolist()
    subset = ds[idxs]
    labels = model.predict(subset, verbose=0)
    
    plt.figure(figsize=(1.5 * w, 1.5 * h))    
    for i, label in enumerate(labels):
        print(label)
        plt.subplot(h, w, i + 1)
        image = subset[i].reshape(32, 32, 3)
#         image = image.astype(np.uint8)
        plt.imshow(image/255)
        plt.title(LABELS[np.argmax(label)])
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout()
    plt.show()

# %%
def plot_history(history, params=['loss', 'acc']):
    for param in params:
        plt.plot(history.history[param], label='train')
        if 'val_%s' % param in history.history.keys():
            plt.plot(history.history['val_%s' % param], label='test')
        plt.xlabel('epoch')
        plt.ylabel(param)
        plt.title(param.capitalize())
        plt.legend()
        plt.show()

# %%
n_channels = 3
LABELS = ['airplane', 'automobile', 'bird', 'cat', 'deer', 
          'dog', 'frog', 'horse', 'ship', 'truck']
n_classes = len(LABELS)

# %%
n_lines_train = 30000
n_lines_test = 10000
(x_train, y_train, x_val, y_val), x_test = load('train.csv', 'test.csv', n_lines_train, n_lines_test)

# %%
print(x_train.shape, len(y_train)) 
print(x_val.shape, len(y_val))
print(x_test.shape)
# Out:
# (24000, 3072) 24000
# (6000, 3072) 6000
# (10000, 3072)

# %%
x_train = x_train.reshape(-1, 32, 32, 3)
x_val = x_val.reshape(-1, 32, 32, 3)
x_test = x_test.reshape(-1, 32, 32, 3)
x_train = x_train[:,:,:,::-1]
x_val = x_val[:,:,:,::-1]
x_test = x_test[:,:,:,::-1]

# %%
print(x_train.shape, len(y_train)) 
print(x_val.shape, len(y_val))
print(x_test.shape)
# Out:
# (24000, 32, 32, 3) 24000
# (6000, 32, 32, 3) 6000
# (10000, 32, 32, 3)

# %%
print('TRAIN')
show_random_images(x_train, y_train, 1, 10)
print('VAL')
show_random_images(x_val, y_val, 1, 10)
print('TEST')
show_random_images(x_test, None, 2, 10)
# Out:
# TRAIN
# VAL
# TEST

# %%
y_train = to_categorical(y_train, 10)
y_val = to_categorical(y_val, 10)

# %%
# x_train = x_train / 255.
# x_val = x_val / 255.
# x_test = x_test / 255.

# %%
def lr_scheduler(epoch):
    lr = 1e-4
    if epoch > 30:
        lr = 5e-5
    if epoch > 50:
        lr = 3e-5
    if epoch > 75:
        lr = 1e-5
#     if epoch > 100:
#         lr = 3e-4
#     if epoch > 100:
#         lr = 3e-4
#     if epoch > 100:
#         lr = 3e-4
#     if epoch > 100:
#         lr = 3e-4
    return lr
#  From cinic cnn
# def lr_scheduler(epoch):
#     lr = 1e-3
#     if epoch > 50:
#         lr = 5e-4
#     if epoch > 100:
#         lr = 3e-4
#     if epoch > 150:
#         lr = 2e-4
#     if epoch > 200:
#         lr = 1e-4
#     if epoch > 250:
#         lr = 5e-5
#     return lr

# %%
def build_model():
    
    inputs = Input(shape=(32, 32, 3))
    inputs = Lambda(lambda image: preprocess_input(ktf.image.resize_images(image, (150, 150))))(inputs)
    
    base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=inputs)
    for layer in base_model.layers:
        layer.trainable = False      
    
    x = base_model.output

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.4)(x)
#  BGR cinic-10 val acc = 55% (only head)
#     x = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
#     x = Dropout(0.3)(x)

#     x = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
#     x = Dropout(0.3)(x)
    
#     x = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
#     x = Dropout(0.2)(x)

    #  cifar-10 val acc = 85% (head -> head + backbone ([249:], last inception block))
    x = Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = Dense(n_classes, activation='softmax')(x)
    
    model = Model(base_model.inputs, x)
    
    opt = rmsprop(lr=1e-4)  # mb 1e-3?
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 150, 150, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 74, 74, 32)   864         lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 74, 74, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 74, 74, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 72, 72, 32)   9216        activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 72, 72, 32)   96          conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 72, 72, 32)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 72, 72, 64)   18432       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 72, 72, 64)   192         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 72, 72, 64)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 35, 35, 64)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 35, 35, 80)   5120        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 35, 35, 80)   240         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 35, 35, 80)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 33, 33, 192)  138240      activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 33, 33, 192)  576         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 33, 33, 192)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 192)  0           activation_99[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 64)   12288       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 64)   192         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 16, 16, 48)   9216        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 16, 16, 96)   55296       activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 48)   144         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 96)   288         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 16, 16, 48)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 96)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 16, 16, 192)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 16, 16, 64)   12288       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 16, 16, 64)   76800       activation_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 96)   82944       activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 16, 16, 32)   6144        average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 16, 16, 64)   192         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 16, 16, 64)   192         conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 96)   288         conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 32)   96          conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 16, 16, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 16, 16, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 96)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 32)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 16, 16, 256)  0           activation_100[0][0]
#                                                                  activation_102[0][0]
#                                                                  activation_105[0][0]
#                                                                  activation_106[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 16, 16, 64)   192         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 16, 16, 64)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 16, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 16, 96)   55296       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 48)   144         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 16, 16, 96)   288         conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 48)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 16, 16, 96)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 16, 16, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 16, 16, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 64)   76800       activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 16, 96)   82944       activation_111[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 64)   16384       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 64)   192         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 16, 16, 64)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 16, 16, 96)   288         conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 16, 16, 64)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 64)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 16, 16, 64)   0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 16, 16, 96)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 16, 16, 64)   0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 16, 16, 288)  0           activation_107[0][0]
#                                                                  activation_109[0][0]
#                                                                  activation_112[0][0]
#                                                                  activation_113[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 16, 16, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 16, 16, 64)   192         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 16, 16, 64)   0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 16, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 16, 16, 96)   55296       activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 16, 16, 48)   144         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 16, 16, 96)   288         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 16, 16, 48)   0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 16, 16, 96)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 16, 16, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 64)   76800       activation_115[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 96)   82944       activation_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 16, 16, 64)   18432       average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 16, 16, 64)   192         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 16, 16, 64)   192         conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 16, 16, 96)   288         conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 16, 16, 64)   192         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 16, 16, 64)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 16, 16, 64)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 16, 16, 96)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 16, 16, 64)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 16, 16, 288)  0           activation_114[0][0]
#                                                                  activation_116[0][0]
#                                                                  activation_119[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 16, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 16, 16, 64)   192         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 16, 16, 64)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 16, 96)   55296       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 16, 16, 96)   288         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 16, 16, 96)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 7, 7, 384)    995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 7, 7, 96)     82944       activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 7, 7, 384)    1152        conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 7, 7, 96)     288         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 7, 7, 384)    0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 7, 7, 96)     0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 288)    0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 7, 7, 768)    0           activation_121[0][0]
#                                                                  activation_124[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 7, 7, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 7, 7, 128)    384         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None,
conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 3, 3, 448)    0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 3, 3, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 3, 3, 384)    1548288     activation_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 3, 3, 384)    1152        conv2d_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 3, 3, 384)    1152        conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 3, 3, 384)    0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 3, 3, 384)    0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 3, 3, 384)    442368      activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 3, 3, 384)    442368      activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 3, 3, 384)    442368      activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 3, 3, 384)    442368      activation_176[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 3, 3, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 3, 3, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 3, 3, 384)    1152        conv2d_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 3, 3, 384)    1152        conv2d_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 3, 3, 384)    1152        conv2d_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 3, 3, 384)    1152        conv2d_178[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 3, 3, 192)    245760      average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 3, 3, 320)    960         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 3, 3, 384)    0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 3, 3, 384)    0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 3, 3, 384)    0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 3, 3, 384)    0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 3, 3, 192)    576         conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 3, 3, 320)    0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 3, 3, 768)    0           activation_173[0][0]
#                                                                  activation_174[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 3, 3, 768)    0           activation_177[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 3, 3, 192)    0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 3, 3, 2048)   0           activation_171[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 3, 3, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 3, 3, 448)    1344        conv2d_184[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 3, 3, 448)    0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 3, 3, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 3, 3, 384)    1548288     activation_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 3, 3, 384)    1152        conv2d_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 3, 3, 384)    1152        conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 3, 3, 384)    0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 3, 3, 384)    0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 3, 3, 384)    442368      activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 3, 3, 384)    442368      activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 3, 3, 384)    442368      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 3, 3, 384)    442368      activation_185[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18 (AveragePo (None, 3, 3, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 3, 3, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 3, 3, 384)    1152        conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 3, 3, 384)    1152        conv2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 3, 3, 384)    1152        conv2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 3, 3, 384)    1152        conv2d_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 3, 3, 192)    393216      average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 3, 3, 320)    960         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 3, 3, 384)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 3, 3, 384)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 3, 3, 384)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 3, 3, 384)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 3, 3, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 3, 3, 320)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 3, 3, 768)    0           activation_182[0][0]
#                                                                  activation_183[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 3, 3, 768)    0           activation_186[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 3, 3, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 3, 3, 2048)   0           activation_180[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_4[0][0]
#                                                                  activation_188[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          1049088     dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          32896       dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           1290        dropout_8[0][0]
# ==================================================================================================
# Total params: 23,017,386
# Trainable params: 1,214,602
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
l_sch = LearningRateScheduler(lr_scheduler)
check = ModelCheckpoint('models/model_epoch_{epoch:02d}_val_acc_{val_acc:.5f}.hdf5',
                         monitor='val_acc',
                         mode='max',
                         save_best_only=True)
tb = TensorBoard(log_dir="logs", write_graph=True, write_images=True)

# %%
img_aug_gen = ImageDataGenerator(rotation_range=40,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 horizontal_flip=True, 
                                 zoom_range=0.3)

# %%
x_batch, y_batch = next(img_aug_gen.flow(x_train, y_train, batch_size=25))

plt.figure(figsize=(6,6))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_batch[i].reshape(32,32,3)/255.)
    plt.title(LABELS[np.argmax(y_batch[i])])
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
plt.show()

# %%
history = model.fit_generator(img_aug_gen.flow(x_train, y_train, batch_size=16),
                              steps_per_epoch=x_train.shape[0] // 16,
                              validation_data=(x_val, y_val),
                              callbacks=[tb, l_sch], 
                              epochs=100)
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 30s 20ms/step - loss: 2.3902 - acc: 0.1611 - val_loss: 1.9262 - val_acc: 0.3127
# Epoch 2/100
# 1500/1500 [==============================] - 28s 19ms/step - loss: 2.1756 - acc: 0.2477 - val_loss: 1.6920 - val_acc: 0.4148
# Epoch 3/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 2.0902 - acc: 0.2760 - val_loss: 1.6339 - val_acc: 0.4527
# Epoch 4/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 2.0440 - acc: 0.2971 - val_loss: 1.6108 - val_acc: 0.4560
# Epoch 5/100
# 1500/1500 [==============================] - 26s 17ms/step - loss:

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_1 = model.fit_generator(img_aug_gen.flow(x_train, y_train, batch_size=32),
                              steps_per_epoch=x_train.shape[0] // 32,
                              validation_data=(x_val, y_val),
                              callbacks=[tb], 
                              epochs=100)
# Out:
# Epoch 1/100
# 1562/1562 [==============================] - 52s 33ms/step - loss: 1.1675 - acc: 0.6103 - val_loss: 1.6075 - val_acc: 0.7502
# Epoch 2/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.9913 - acc: 0.6714 - val_loss: 1.2462 - val_acc: 0.7836
# Epoch 3/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.9076 - acc: 0.6985 - val_loss: 1.1880 - val_acc: 0.7970
# Epoch 4/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.8633 - acc: 0.7188 - val_loss: 1.1021 - val_acc: 0.8001
# Epoch 5/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.8234 - acc: 0.7289 - val_loss: 1.4714 - val_acc: 0.7536
# Epoch 6/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.8016 - acc: 0.7363 - val_loss: 1.2550 - val_acc: 0.7806
# Epoch 7/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.7731 - acc: 0.7474 - val_loss: 1.0195 - val_acc: 0.7962
# Epoch 8/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.7481 - acc: 0.7560 - val_loss: 0.7496 - val_acc: 0.8339
# Epoch 9/100
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.7394 - acc: 0.7579 - val_loss: 0.9754 - val_acc: 0.8090
# Epoch 10/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.7144 - acc: 0.7668 - val_loss: 0.7849 - val_acc: 0.8310
# Epoch 11/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.6996 - acc: 0.7697 - val_loss: 0.8530 - val_acc: 0.8201
# Epoch 12/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6942 - acc: 0.7702 - val_loss: 0.9252 - val_acc: 0.8134
# Epoch 13/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6851 - acc: 0.7751 - val_loss: 0.7791 - val_acc: 0.8275
# Epoch 14/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6777 - acc: 0.7786 - val_loss: 0.8356 - val_acc: 0.8196
# Epoch 15/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6591 - acc: 0.7842 - val_loss: 0.9654 - val_acc: 0.8067
# Epoch 16/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6605 - acc: 0.7828 - val_loss: 0.8270 - val_acc: 0.8205
# Epoch 17/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6491 - acc: 0.7868 - val_loss: 0.9111 - val_acc: 0.8096
# Epoch 18/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.6415 - acc: 0.7885 - val_loss: 0.8283 - val_acc: 0.8202
# Epoch 19/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.6323 - acc: 0.7926 - val_loss: 0.7791 - val_acc: 0.8143
# Epoch 20/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.6303 - acc: 0.7922 - val_loss: 0.8314 - val_acc: 0.8202
# Epoch 21/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.6154 - acc: 0.7974 - val_loss: 0.8782 - val_acc: 0.8217
# Epoch 22/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6085 - acc: 0.8019 - val_loss: 0.8213 - val_acc: 0.8211
# Epoch 23/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6062 - acc: 0.8019 - val_loss: 0.7579 - val_acc: 0.8215
# Epoch 24/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.6042 - acc: 0.8016 - val_loss: 0.7475 - val_acc: 0.8247
# Epoch 25/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.5931 - acc: 0.8053 - val_loss: 0.7133 - val_acc: 0.8318
# Epoch 26/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.5915 - acc: 0.8055 - val_loss: 0.8161 - val_acc: 0.8179
# Epoch 27/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.5881 - acc: 0.8084 - val_loss: 0.7086 - val_acc: 0.8300
# Epoch 28/100
# 1562/1562 [==============================] - 46s 29ms/step - loss: 0.
100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4946 - acc: 0.8382 - val_loss: 0.6501 - val_acc: 0.8559
# Epoch 57/100
# 1562/1562 [==============================] - 48s 30ms/step - loss: 0.4891 - acc: 0.8400 - val_loss: 0.9013 - val_acc: 0.8230
# Epoch 58/100
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4902 - acc: 0.8400 - val_loss: 0.7259 - val_acc: 0.8490
# Epoch 59/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4814 - acc: 0.8422 - val_loss: 0.7865 - val_acc: 0.8296
# Epoch 60/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4869 - acc: 0.8406 - val_loss: 0.7846 - val_acc: 0.8433
# Epoch 61/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4873 - acc: 0.8421 - val_loss: 0.7171 - val_acc: 0.8431
# Epoch 62/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.4831 - acc: 0.8424 - val_loss: 0.8625 - val_acc: 0.8222
# Epoch 63/100
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4796 - acc: 0.8444 - val_loss: 0.7695 - val_acc: 0.8409
# Epoch 64/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4800 - acc: 0.8427 - val_loss: 0.7840 - val_acc: 0.8387
# Epoch 65/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4781 - acc: 0.8439 - val_loss: 0.8256 - val_acc: 0.8306
# Epoch 66/100
# 1562/1562 [======?=======================] - 47s 30ms/step - loss: 0.4742 - acc: 0.8463 - val_loss: 0.8437 - val_acc: 0.8302
# Epoch 67/100
# 1562/1562 [==============================] - 46s 30ms/step - loss: 0.4712 - acc: 0.8451 - val_loss: 0.9871 - val_acc: 0.8199
# Epoch 68/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4666 - acc: 0.8479 - val_loss: 0.8762 - val_acc: 0.8289
# Epoch 69/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4675 - acc: 0.8490 - val_loss: 0.9242 - val_acc: 0.8227
# Epoch 70/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4657 - acc: 0.8492 - val_loss: 0.7203 - val_acc: 0.8466
# Epoch 71/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4624 - acc: 0.8476 - val_loss: 0.8930 - val_acc: 0.8257
# Epoch 72/100
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.4624 - acc: 0.8516 - val_loss: 0.7841 - val_acc: 0.8390
# Epoch 73/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4598 - acc: 0.8511 - val_loss: 0.7498 - val_acc: 0.8450
# Epoch 74/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4585 - acc: 0.8513 - val_loss: 0.8155 - val_acc: 0.8377
# Epoch 75/100
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4591 - acc: 0.8508 - val_loss: 0.8255 - val_acc: 0.8346
# Epoch 76/100
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4603 - acc: 0.8516 - val_loss: 0.7162 - val_acc: 0.8438
# Epoch 77/100
# 1460/1562 [===========================>..] - ETA: 2s - loss: 0.4504 - acc: 0.8526

# %%
plot_history(history_1)

# %%
acc = model.evaluate(x_train, y_train, verbose=0)[1]
print('Model train acc: %0.2f%%' % (100 * acc))

val_acc = model.evaluate(x_val, y_val, verbose=0)[1]
print('Model val acc: %0.2f%%' % (100 * val_acc))
# Out:
# Model train acc: 55.99%
# Model val acc: 55.30%

# %%
y_pred = predict(model, x_test, 'submissions/submission_3_%0.5f.csv' % val_acc)

# %%
model.save('model_val_acc_%0.4f.hdf5' % val_acc)

# %%
plt.imshow(x_test[1]/255.)

# %%
model_proc = Model(model.input, model.layers[1].output)

# %%
plt.imshow((model_proc.predict(np.expand_dims(x_test[1], axis=0))[0]+1)/2)
